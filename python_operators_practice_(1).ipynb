# %% [markdown]
# <a href="https://colab.research.google.com/github/muskaan0409/python-basis/blob/main/python_operators_practice_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Python Operators Practice Notebook
#
# Each question is followed by its solution in the next code cell.
# Difficulty level: Easy to Medium.

# %% [markdown]
# ## Arithmetic Operators

# %% [markdown]
# Q1. Add two numbers a = 10 and b = 5.

# %%
# write your answer here
a=12
b=13
c=a+b
print(c)
# Out:
# 25

# %% [markdown]
# Q2. Find the remainder when 17 is divided by 4.

# %%
# write your answer here
y=17%4
print(y)
# Out:
# 1

# %% [markdown]
# Q3. Calculate 3 raised to the power 4.

# %%
# write your answer here
y=3**4
print(y)
# Out:
# 81

# %% [markdown]
# ## Assignment Operators

# %% [markdown]
# Q4. Assign 10 to x and add 5 to it using assignment operator.

# %%
# write your answer here
x=10
x=x+5
print(x)

# %% [markdown]
# Q5. Assign 20 to y and multiply it by 2 using assignment operator.

# %%
# write your answer here
y=20
y=y*2
print(y)
# Out:
# 40

# %% [markdown]
# Q6. Assign 15 to z and subtract 7 using assignment operator.

# %%
# write your answer here
z=15
z=z-7
print(z)
# Out:
# 8

# %% [markdown]
# ## Comparison Operators

# %% [markdown]
# Q7. Check if 10 is greater than 5.

# %%
# write your answer here
if 10>5:
  print("yes")
else:
  print("no")
# Out:
# yes

# %% [markdown]
# Q8. Check if 7 is equal to 9.

# %%
# write your answer here
if 7==9:
  print("true")
else:
  print("false")

# %% [markdown]
# Q9. Check if 8 is not equal to 3.

# %%
# write your answer here
if 8==3:
  print("true")
else:
  print("false")
# Out:
# false

# %% [markdown]
# ## Logical Operators

# %% [markdown]
# Q10. Check if 5 > 2 and 10 > 3.

# %%
# write your answer here
if 5>2 and 10>3:
  print("true")
# Out:
# true

# %% [markdown]
# Q11. Check if 5 > 10 or 3 < 7.

# %%
# write your answer here
if 5>10 or 3<7:
  print("true")
else:
  print("false")
# Out:
# true

# %% [markdown]
# Q12. Use not operator on condition 10 > 5.

# %%
# write your answer here
if  not 10>5:
  print("true")

# %% [markdown]
# ## Identity Operators

# %% [markdown]
# Q16. Check if a and b refer to the same object.
# Let a = 10, b = 10.

# %%
# write your answer here
a=int(input("enter the number1:"))
b=int(input("enter the number2:"))
if a is b:
  print("true")
else:
  print("false")
# Out:
# enter the number1:10
# enter the number2:10
# true

# %% [markdown]
# Q18. Compare identity of two variables c and d where c = d = 5.

# %%
# write your answer here
a=int(input("enter the number1:"))
b=int(input("enter the number2:"))
if a == b:
  print("true")
else:
  print("false")

# %% [markdown]
# ## Membership Operators

# %% [markdown]
# Q19. Check if 3 is present in the list [1,2,3,4].

# %%
# write your answer here
a=[1,2,3,4]
if 3 in a:
  print("yes")
# Out:
# yes

# %% [markdown]
# Q20. Check if 'a' is not present in the string 'python'.

# %%
# write your answer here
a="python"
if "a" in a:
  print("yes")
else:
  print('no')
# Out:
# no

# %% [markdown]
# Q21. Check if 10 is in the tuple (5, 10, 15).

# %%
# write your answer here
a=(5,10,15)
if 10 in a:
  print("true")
else:
  print("no")
# Out:
# true
