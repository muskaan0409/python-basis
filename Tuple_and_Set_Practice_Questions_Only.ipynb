# %% [markdown]
# <a href="https://colab.research.google.com/github/muskaan0409/python-basis/blob/main/Tuple_and_Set_Practice_Questions_Only.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Python Practice: Tuple and Set (Practice Only)
#
# This notebook contains **practice questions only** on **Tuples** and **Sets**.
#
# Instructions:
# - Questions are written in **text cells**
# - Write your solution in the **code cell below each question**
# - Do NOT use any advanced concepts

# %% [markdown]
# ##  Tuple Practice Questions

# %% [markdown]
# ### Question 1
# Create a tuple of 5 integers and print it.

# %%
# write your answer here
tup1=(1,2,3,4,5)
print(tup1)
# Out:
# (1, 2, 3, 4, 5)

# %% [markdown]
# ### Question 2
# Create a tuple with different data types (int, float, string, boolean) and print each element separately.

# %%
# write your answer here
tup1=(1,"aman",3.4,True)
for x in range(4):
  print(tup1[x])
# Out:
# 1
# aman
# 3.4
# True

# %% [markdown]
# ### Question 3
# Find the length of a tuple containing names of 4 students.

# %%
# write your answer here
tup1="aman","sujal","aditi","komal"
print(len(tup1))
# Out:
# 4

# %% [markdown]
# ### Question 4
# Access and print the last element of a tuple.

# %%
# write your answer here
tup1="aman","sujal","aditi","komal"
print(tup1[-1])
# Out:
# komal

# %% [markdown]
# ### Question 5
# Check whether an element exists in a tuple or not.

# %%
# write your answer here

tup1="aman","sujal","aditi","komal"
#print(tup1.count("aman"))
if "aman" in tup1:
  print("yes")
# Out:
# 1
# yes

# %% [markdown]
# ### Question 6
# Convert a tuple into a list.

# %%
# write your answer here
tup1="aman","sujal","aditi","komal"
m=list(tup1)
print(m)
# Out:
# ['aman', 'sujal', 'aditi', 'komal']

# %% [markdown]
# ### Question 7
# Convert a list into a tuple.

# %%
# write your answer here
a=['aman', 'sujal', 'aditi', 'komal']
b=tuple(a)
print(b)
# Out:
# ('aman', 'sujal', 'aditi', 'komal')

# %% [markdown]
# ### Question 8
# Create a tuple with repeated values and count how many times an element appears.

# %%
# write your answer here
a=['aman', 'sujal', 'aditi', 'komal',"lion","aman","sujal"]
for x in a:
  print(x,a.count(x))
#print(a.count("aman"))
# Out:
# aman 2
# sujal 2
# aditi 1
# komal 1
# lion 1
# aman 2
# sujal 2

# %% [markdown]
# ### Question 9
# Find the index of an element in a tuple.

# %%
# write your answer here
# write your answer here
a=('aman', 'sujal', 'aditi', 'komal',"lion","aman","sujal")
print(a.index("aman"))
# Out:
# 0

# %% [markdown]
# ### Question 10
# Demonstrate that tuples are immutable (cannot be changed).

# %%
# write your answer here
# write your answer here
a=('aman', 'sujal', 'aditi', 'komal',"lion","aman","sujal")
a[0]="payal"
#comment this will throw an error
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2528401485.py in <cell line: 0>()
#       2 # write your answer here
#       3 a=('aman', 'sujal', 'aditi', 'komal',"lion","aman","sujal")
# ----> 4 a[0]="payal"
#
# TypeError: 'tuple' object does not support item assignment
