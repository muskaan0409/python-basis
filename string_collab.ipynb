# %% [markdown]
# <a href="https://colab.research.google.com/github/muskaan0409/python-basis/blob/main/string_collab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
text =input("Enter the string:")

for ch in text:
    if text.count(ch) > 1:
        print(ch, "is repested")
# Out:
# Enter the string:india
# i is repested
# i is repested

# %%
var=input("Enter Your String: ")

x=0
for i in var:
  if i==x:
    continue
  if var.count(i)>1:
    x=i
    print(i)
# Out:
# Enter Your String: india
# i

# %%
fn= "Rohit Kumar Yadav"
print(fn.split(" "))
# Out:
# ['Rohit', 'Kumar', 'Yadav']

# %%
text=["Hence", "proved", "prem", "gandu", "hai"]
print(" ".join(text))
# Out:
# Hence proved prem gandu hai

# %%
var = "india"
l = len(var)

print(var)

for i in range(1):
    print(var[i], end="")
print()
for i in range(l):
  print(var[i],end=" ")
print()
for i in range(l):
  print(i,end="")
# Out:
# india
# i
# i n d i a
# 01234

# %%
#Find & count
Name="Rohit Kumar"
print(Name.find("r"))
print(Name.count("r"))
# Out:
# 10
# 1

# %%
#String checking Function
name="RohitK"
print(name.isalpha())
print(name.isdigit())
print(name.isalnum())
print(name.startswith("M"))
print(name.endswith(".com"))
# Out:
# True
# False
# True
# False
# False

# %%
#Strip = which is used to remove extra space

name="    Rohit    "
print(name)
print(name.strip())
# Out:
#     Rohit
# Rohit

# %%
#1. length
#2. case conversion

name="Rohit Kumar"
print(name.lower())
print(name.upper())
print(name.title())
# Out:
# rohit kumar
# ROHIT KUMAR
# Rohit Kumar

# %%
name=input("Enter your name:")
print(name[-1::-1])
print(name[0:1])
print(name[-1:-2:-1])
print(name[0:3])
# Out:
# Enter your name:muskan
# naksum
# m
# n
# mus

# %%
#Reverse the string
name="Acciojob"
print(name[-1::-1])
print(name[::2])
# Out:
# bojoiccA
# Acoo

# %%
name="Rohit"
print(name[0:4])
print(name[-1:-2:-1]) #step must be there
# Out:
# Rohi
# t

# %%
course="python"
print(len(course))
print(type(course))
# Out:
# 6
# <class 'str'>
